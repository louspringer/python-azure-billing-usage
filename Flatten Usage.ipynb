# %%
import pickle
df_usage = pickle.load( open( "df_usage.p", "rb" ) )
df_usage
# Out:
#                                                  value  \
# 0    {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 1    {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 2    {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 3    {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 4    {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 5    {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 6    {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 7    {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 8    {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 9    {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 10   {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 11   {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 12   {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 13   {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 14   {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# 15   {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc...
# ...
