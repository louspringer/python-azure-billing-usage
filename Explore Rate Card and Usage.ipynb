# %%
import adal
from msrestazure.azure_active_directory import AADTokenCredentials
from dotenv import load_dotenv, find_dotenv
import os
load_dotenv(find_dotenv())
# Out:
# True

# %%
os.getenv("AZURE_SUBSCRIPTION")

# %%
import requests
 
# Parameters need for API
subscription = os.getenv("AZURE_SUBSCRIPTION_ID")
tenant = os.getenv("AZURE_TENANT_ID")
client_id = os.getenv("AZURE_CLIENT_ID")
client_secret = os.getenv("AZURE_CLIENT_SECRET")
offer = 'MS-AZR-0003P'
currency = 'USD'
locale = 'en-US'
region = 'US'

# %%
def authenticate_client_key(tenant, client_id, client_secret):
    """
    Authenticate using service principal w/ key.
    """
    authority_host_uri = 'https://login.microsoftonline.com'
    authority_uri = authority_host_uri + '/' + tenant
    resource_uri = 'https://management.core.windows.net/'
    
    context = adal.AuthenticationContext(authority_uri, api_version=None)
    mgmt_token = context.acquire_token_with_client_credentials(resource_uri, client_id, client_secret)
    credentials = AADTokenCredentials(mgmt_token, client_id)

    return credentials

# %%
credentials = authenticate_client_key(tenant, client_id, client_secret)
access_token = credentials.token.get('access_token')

# %%
azure_mgmt_uri = 'https://management.azure.com:443/subscriptions/{subscriptionId}'.format(subscriptionId = subscription)

# %%
azure_mgmt_uri
# Out:
# 'https://management.azure.com:443/subscriptions/3e6b71a1-1c47-4188-a4dc-793259a87549'

# %%
# Azure Resource RateCard API 
# https://docs.microsoft.com/en-us/azure/billing/billing-usage-rate-card-overview
uri_str = "{azure_mgmt_uri}/providers/Microsoft.Commerce/RateCard?" + \
    "api-version=2016-08-31-preview&$filter=OfferDurableId eq '{offerId}' and " + \
    "Currency eq '{currencyId}' and Locale eq '{localeId}' and RegionInfo eq '{regionId}'"
    
rateCardUrl = uri_str.format(
    azure_mgmt_uri = azure_mgmt_uri,
    offerId = offer, 
    currencyId = currency, 
    localeId = locale, 
    regionId = region)

# Don't allow redirects and call the RateCard API
response = requests.get(rateCardUrl, allow_redirects=False, headers = {'Authorization': 'Bearer %s' %access_token})

# Look at response headers to get the redirect URL
redirectUrl = response.headers['Location']

# Get the ratecard content by making another call to go the redirect URL
rateCard = requests.get(redirectUrl)

# %%
import pandas as pd
import json

# %%
r = json.loads(rateCard.content.decode("utf-8"))
df_rates = pd.DataFrame.from_dict(r['Meters'])
df_rates
# Out:
#               EffectiveDate  IncludedQuantity                  MeterCategory  \
# 0      2017-04-01T00:00:00Z               0.0               Virtual Machines
# 1      2017-02-01T00:00:00Z               0.0                  Data Services
# 2      2014-05-01T00:00:00Z               0.0               Virtual Machines
# 3      2017-10-20T00:00:00Z               0.0                 Cloud Services
# 4      2016-02-01T00:00:00Z               0.0                 Cloud Services
# 5      2018-07-13T00:00:00Z               0.0                        Storage
# 6      2016-02-01T00:00:00Z               0.0                 Cloud Services
# 7      2017-01-01T00:00:00Z               0.0                        Storage
# 8      2016-09-01T00:00:00Z               0.0             SQL Data Warehouse
# 9      2017-11-03T00:00:00Z               0.0                 Cloud Services
# 10     2017-04-01T00:00:00Z               0.0               Virtual Machines
# 11     2018-07-13T00:00:00Z               0.0                        Storage
# 12     2017-11-03T00:00:00Z               0.0               Virtual Machines
# 13     2018-05-01T00:00:00Z               0.0  Azure Database for PostgreSQL
# 14     2018-09-01T00:00:00Z               0.0               Virtual Machines
# 15     2018-09-04T00:00:00Z               0.0                   SQL Database
# 16     2018-02-28T00:00:00Z               0.0               Virtual Machines
# 17     2017-07-21T00:00:00Z               0.0               Virtual Machines
# 18     2018-07-20T00:00:00Z               0.0                        Storage
# 19     2018-02-28T00:00:00Z               0.0               Virtual Machines
# 20     2017-12-15T00:00:00Z               0.0                   App Services
# 21     2016-10-01T00:00:00Z               0.0             Cognitive Services
# 22     2018-07-20T00:00:00Z               0.0                        Storage
# 23     2017-02-01T00:00:00Z               0.0                 Cloud Services
# 24     2018-07-20T00:00:00Z               0.0                        Storage
# 25     2017-02-01T00:00:00Z               0.0                 Cloud Services
# 26     2018-02-14T00:00:00Z               0.0                 Cloud Services
# 27     2017-07-21T00:00:00Z               0.0                 Cloud Services
# 28     2017-10-01T00:00:00Z               0.0                        Storage
# 29     2015-06-01T00:00:00Z               0.0                        Storage
# ...                     ...               ...                            ...
# 30961  2018-05-01T00:00:00Z               0.0  Azure Database for PostgreSQL
# 30962  2017-10-03T00:00:00Z               0.0                  Data Services
# 30963  2016-11-01T00:00:00Z               0.0               Virtual Machines
# 30964  2018-02-28T00:00:00Z               0.0               Virtual Machines
# 30965  2018-02-14T00:00:00Z               0.0               Virtual Machines
# 30966  2017-12-15T00:00:00Z               0.0                 Cloud Services
# 30967  2017-12-01T00:00:00Z               0.0               Virtual Machines
# 30968  2017-08-01T00:00:00Z               0.0                        Storage
# 30969  2017-11-03T00:00:00Z               0.0                 Cloud Services
# 30970  2017-11-03T00:00:00Z               0.0               Virtual Machines
# 30971  2017-11-03T00:00:00Z               0.0               Virtual Machines
# 30972  2017-08-18T00:00:00Z               0.0               Virtual Machines
# 30973  2017-04-01T00:00:00Z               0.0               Virtual Machines
# 30974  2018-05-11T00:00:00Z               0.0               Virtual Machines
# 30975  2017-03-01T00:00:00Z               0.0               Virtual Machines
# 30976  2014-12-01T00:00:00Z               0.0                 Cloud Services
# 30977  2018-04-27T00:00:00Z               0.0               Virtual Machines
# 30978  2017-04-01T00:00:00Z               0.0               Virtual Machines
# 30979  2017-09-19T00:00:00Z               0.0                  Data Services
# 30980  2016-02-22T00:00:00Z               0.0                Data Management
# 30981  2018-08-17T00:00:00Z               0.0               Virtual Machines
# 30982  2017-11-03T00:00:00Z               0.0               Virtual Machines
# 30983  2016-07-01T00:00:00Z               0.0               Virtual Machines
# 30984  2018-05-11T00:00:00Z               0.0                        Storage
# 30985  2018-03-28T00:00:00Z               0.0                        Storage
# 30986  2018-02-28T00:00:00Z               0.0                   SQL Database
# 30987  2018-08-01T00:00:00Z               0.0                   SQL Database
# 30988  2018-06-01T00:00:00Z               0.0                        Storage
# 30989  2017-10-01T00:00:00Z               0.0                        Storage
# 30990  2017-11-03T00:00:00Z               0.0               Virtual Machines
#
#                                     MeterId  \
# 0      d0bf9053-17c4-4fec-8502-4eb8376343a7
# 1      8b7672d4-16fc-446e-9935-cf2223c5290f
# 2      2c4db260-4bc7-4388-a42f-b0c709255ae8
# 3      c9c058cb-822e-46ae-86fb-6b583f91b4b5
# 4      0aaf975b-8e33-404b-93f7-de7d69774ca1
# 5      e1e7c9cb-ed36-4f0b-b3f5-c3dead188ef4
# 6      77860eb6-e2bc-4d06-8efe-491d840adaf5
# 7      8ebaf4a8-960b-457b-ba6b-70b59c959ec7
# 8      22e690b0-183e-4266-bbeb-0c8ccf98f160
# 9      1c389e44-fc99-46dd-93b4-5aab8f611ccc
# 10     241669f0-6b85-49a2-9bb1-dbe4996f38e8
# 11     d47d7a11-6aa5-4197-80a4-f3ca26d98523
# 12     1dfddd5d-9ff3-4880-825f-e8f4e677d981
# 13     fa22482b-bdf3-4096-91f4-cc163a73067f
# 14     b23d2b67-241d-46c7-b844-26bd2fb4e28b
# 15     0d52b47b-4960-456c-98c6-8402d001c90e
# 16     d1ff3c06-f95c-44db-a35b-5fec56696cfe
# 17     5a94d716-e0af-46da-8be7-cd0ff915048d
# 18     99bcc7bb-9ead-4d54-a632-507ad1e4e68b
# 19     f5730a2a-2d31-4e78-b70e-4b8c88c46236
# 20     aa807928-96d4-4f53-a978-5372b81a4f89
# 21     2a9b16cf-2b54-4f0a-93ca-232f83502b7b
# 22     c44913cc-c24e-4f01-9fb8-75dedbb08e19
# 23     1b785b8a-c818-4131-aa73-31d59f6b5a3f
# 24     17626953-0143-4f31-b5a4-d27b9159d700
# 25     7c901a8a-4979-4a7a-afac-3d49a0f6fc22
# 26     37103b93-94f0-4093-b204-04d8cb36b0e4
# 27     1a63414f-7ce3-4298-875b-5f324434c159
# 28     e86146db-e868-41bf-a1dd-98c927abf13d
# 29     c069fd89-c3ce-4caa-b018-0bc26dd0a6a9
# ...                                     ...
# 30961  3fdafcd3-a494-4456-8e7f-216be32aff5d
# 30962  9fcf66b8-4210-49b0-b494-3317382bc6cc
# 30963  5c54154b-efc5-44d3-b55c-51cd4b08d710
# 30964  0bff0482-5bd0-4dfe-a77b-044755d65a9f
# 30965  24a4176b-caeb-487b-ae30-a1a57df37154
# 30966  323ca957-eea0-4e0a-9a92-ab9b620eb98c
# 30967  e4a5968d-fb1e-48b7-9520-d3150c714363
# 30968  f6bfb57a-4154-46c3-9d13-53fe4e529699
# 30969  03c2aeaa-b8aa-4bba-b3d6-80ee261967f9
# 30970  a378127f-ac54-431c-89ec-9b880de980ed
# 30971  12c1a277-5baa-46af-8438-794269f83ecc
# 30972  0f42cb3c-4bb2-4ead-bfac-687f6bb7f730
# 30973  768ff130-a8a1-49c1-9506-fe3fe5b29051
# 30974  d2ce791a-13cc-4999-8d4d-a15b860fc72b
# 30975  028967ae-4f16-4e72-b78d-c8a4314e40a1
# 30976  95b38082-a0db-474c-9fca-5650c639fb9b
# 30977  97cfd790-7525-47e8-8e5c-0a3722203443
# 30978  ddfbab12-75cd-4986-a872-800234e50209
# 30979  382d49a4-3d9b-45ea-bf9d-a19a79171d72
# 30980  13553d04-5057-4557-872b-cafaf85e256a
# 30981  a0716d5a-2c14-4fae-8ed1-d52b9812e329
# 30982  47baac53-00f2-48ef-a35e-f7227c0eb130
# 30983  70653a90-aede-4e59-a122-265a80801f27
# 30984  7fe704d0-2144-4b35-854a-78fd64bbc9e6
# 30985  a3cd5202-563a-4b0d-9d58-0ad494c62215
# 30986  644a585e-7cac-4264-8be5-8e458e92ba00
# 30987  9da7ff6e-a685-4b36-9f9d-48fcbd3f220c
# 30988  51fd764c-2df2-4aa4-a240-0c271e846e26
# 30989  e2f7a370-4a77-478b-b258-85677c2041bf
# 30990  78ee8f2c-813d-40b2-ad80-8df9c56c7920
#
#                                          MeterName        MeterRates  \
# 0                              F2/F2s Low Priority      {'0': 0.077}
# 1              Standard S3 Secondary Database Days     {'0': 4.0177}
# 2                                               A6       {'0': 0.64}
# 3                                    Compute Hours      {'0': 4.676}
# 4                                    Compute Hours       {'0': 0.14}
# 5                       Archive Read Additional IO      {'0': 0.039}
# 6                                    Compute Hours      {'0': 3.518}
# 7          Premium Storage - Page Blob/P60 (Units)     {'0': 946.08}
# 8                                          100 DWU     {'0': 1.5121}
# 9                                    Compute Hours       {'0': 3.04}
# 10                             A8m v2 Low Priority      {'0': 0.183}
# 11                 Archive GRS Write Additional IO     {'0': 0.0273}
# 12                               L32s Low Priority      {'0': 0.598}
# 13                                           vCore     {'0': 0.0408}
# 14                          D3 v2/DS3 v2 - Expired      {'0': 0.588}
# 15                              IO Rate Operations       {'0': 0.22}
# 16                       D2 v2/DS2 v2 Low Priority     {'0': 0.1475}
# 17                                    E2 v3/E2s v3      {'0': 0.248}
# 18                     Hot GRS Write Additional IO      {'0': 0.013}
# 19                              A8 v2 Low Priority       {'0': 0.35}
# 20                    Log Analytics Data Retention       {'0': 0.14}
# 21                                S2 (Daily Units)  {'0': 22.580645}
# 22             Cool GRS Iterative Write Operations        {'0': 0.1}
# 23                                   Compute Hours     {'0': 0.3638}
# 24              Cool GRS Iterative Read Operations       {'0': 0.05}
# 25                                   Compute Hours      {'0': 1.525}
# 26                                   Compute Hours       {'0': 7.08}
# 27                                   Compute Hours      {'0': 1.672}
# 28               Standard Managed Disk/S15 (Units)    {'0': 12.4608}
# 29         Premium Storage - Page Blob/P10 (Units)      {'0': 20.61}
# ...                                            ...               ...
# 30961                                  Data Stored      {'0': 0.276}
# 30962                     Gen Pur vCore ReadRep G4    {'0': 0.06475}
# 30963                                       A2m v2      {'0': 0.225}
# 30964                                          B2s       {'0': 0.08}
# 30965                              A6 Low Priority    {'0': 0.13875}
# 30966                                Compute Hours      {'0': 3.008}
# 30967                              A2 Low Priority     {'0': 0.0564}
# 30968  GPv2 Std IO - Page Blob Read Addtl IO Units    {'0': 0.00017}
# 30969                                Compute Hours      {'0': 9.613}
# 30970                          F1/F1s Low Priority      {'0': 0.011}
# 30971                          F2/F2s Low Priority      {'0': 0.074}
# 30972                            M64s Low Priority      {'0': 1.867}
# 30973                                          L4s      {'0': 0.528}
# 30974                  E20 v3/E20s v3 Low Priority       {'0': 1.01}
# 30975                              A5 Low Priority      {'0': 0.044}
# 30976                                Compute Hours       {'0': 0.64}
# 30977                           M32ms Low Priority     {'0': 5.8463}
# 30978                           NC24r Low Priority        {'0': 1.4}
# 30979                                   MI IO Rate       {'0': 0.11}
# 30980            Geo-Replicated Data Transfer (GB)       {'0': 0.16}
# 30981                                         B1ms     {'0': 0.0257}
# 30982                        NC24s v2 Low Priority      {'0': 3.469}
# 30983                                Compute Hours        {'0': 9.0}
# 30984        GPv2 Std IO - File Protocol Ops Units     {'0': 0.0015}
# 30985                      Cool Read Additional IO     {'0': 0.0025}
# 30986                                        vCore   {'0': 0.365322}
# 30987                                  Data Stored     {'0': 0.1357}
# 30988        GPv2 Std IO - Queue Class 1 Ops Units      {'0': 0.004}
# 30989             Standard Managed Disk/S6 (Units)     {'0': 4.8128}
# 30990                  D13 v2/DS13 v2 Low Priority      {'0': 0.152}
#
#             MeterRegion MeterStatus  \
# 0             US West 2      Active
# 1              KR South      Active
# 2          AP Southeast      Active
# 3               AU East      Active
# 4               US West      Active
# 5               AU East      Active
# 6               AP East      Active
# 7               US West      Active
# 8            US Central      Active
# 9               JA West      Active
# 10             BR South      Active
# 11              US East      Active
# 12         AP Southeast      Active
# 13     US South Central      Active
# 14           FR Central      Active
# 15           CA Central      Active
# 16         AU Central 2      Active
# 17           FR Central      Active
# 18              JA East      Active
# 19         AU Central 2      Active
# 20             KR South      Active
# 21                           Active
# 22              JA East      Active
# 23            US Gov TX      Active
# 24             IN South      Active
# 25            US Gov TX      Active
# 26             UK South      Active
# 27              US West      Active
# 28           IN Central      Active
# 29              JA West      Active
# ...                 ...         ...
# 30961           AU East      Active
# 30962      AP Southeast      Active
# 30963           AU East      Active
# 30964      AU Central 2      Active
# 30965        AU Central      Active
# 30966         US West 2      Active
# 30967          IN South      Active
# 30968           JA West      Active
# 30969           US East      Active
# 30970           IN West      Active
# 30971        KR Central      Active
# 30972           EU West      Active
# 30973           US West      Active
# 30974        KR Central      Active
# 30975         US West 2      Active
# 30976        US Central      Active
# 30977           AU East      Active
# 30978           JA East      Active
# 30979           IN West      Active
# 30980          BR South      Active
# 30981           CA East      Active
# 30982         US West 2      Active
# 30983                        Active
# 30984           US East      Active
# 30985        AU Central      Active
# 30986        US Central      Active
# 30987        KR Central      Active
# 30988        FR Central      Active
# 30989           AU East      Active
# 30990           IN West      Active
#
#                                         MeterSubCategory MeterTags  \
# 0                                    F/FS Series Windows        []
# 1                                           SQL Database        []
# 2                                       A Series Windows        []
# 3              Standard_H16r Cloud Services Low Priority        []
# 4                          Standard_D1_v2 Cloud Services        []
# 5      Azure Data Lake Storage Gen2 Hierarchical Name...        []
# 6                         Standard_D15_v2 Cloud Services        []
# 7                                      Locally Redundant        []
# 8                                 Compute Optimized Gen1        []
# 9            Standard_E64_v3 Cloud Services Low Priority        []
# 10                                            Av2 Series        []
# 11     Azure Data Lake Storage Gen2 Hierarchical Name...        []
# 12                                             LS Series        []
# 13                                    Basic Compute Gen5        []
# 14                         Dv2/DSv2 Promo Series Windows        []
# 15            Managed Instance General Purpose - Storage        []
# 16                               Dv2/DSv2 Series Windows        []
# 17                               Ev3/ESv3 Series Windows        []
# 18     Azure Data Lake Storage Gen2 Hierarchical Name...        []
# 19                                    Av2 Series Windows        []
# 20                                                              []
# 21                                    Custom Recognition        []
# 22           Azure Data Lake Storage Gen2 Flat Namespace        []
# 23                        Standard_D11_v2 Cloud Services        []
# 24           Azure Data Lake Storage Gen2 Flat Namespace        []
# 25                            Standard_G2 Cloud Services        []
# 26                        Standard_F64_v2 Cloud Services        []
# 27                        Standard_D16_v3 Cloud Services        []
# 28                                     Locally Redundant        []
# 29                                     Locally Redundant        []
# ...                                                  ...       ...
# 30961                             Perf Optimized Storage        []
# 30962                           Azure Database for MySQL        []
# 30963                                 Av2 Series Windows        []
# 30964                                          BS Series        []
# 30965                                           A Series        []
# 30966                     Standard_D32_v3 Cloud Services        []
# 30967                             A Series Basic Windows        []
# 30968                                                           []
# 30969                       Standard_M64s Cloud Services        []
# 30970                                        F/FS Series        []
# 30971                                F/FS Series Windows        []
# 30972                                          MS Series        []
# 30973                                  LS Series Windows        []
# 30974                            Ev3/ESv3 Series Windows        []
# 30975                                           A Series        []
# 30976                                  A4 Cloud Services        []
# 30977                                  MS Series Windows        []
# 30978                                          NC Series        []
# 30979                                       SQL Database        []
# 30980                                                           []
# 30981                                          BS Series        []
# 30982                               NCSv2 Series Windows        []
# 30983                    SQL Server Enterprise (24 core)        []
# 30984                                     Zone Redundant        []
# 30985        Azure Data Lake Storage Gen2 Flat Namespace        []
# 30986  Single/Elastic Pool Business Critical - Comput...        []
# 30987      Single/Elastic Pool General Purpose - Storage        []
# 30988                                     Zone Redundant        []
# 30989                                  Locally Redundant        []
# 30990                                    Dv2/DSv2 Series        []
#
#                  Unit
# 0              1 Hour
# 1                Days
# 2              1 Hour
# 3              1 Hour
# 4               Hours
# 5      10K Operations
# 6               Hours
# 7               Units
# 8               Hours
# 9              1 Hour
# 10             1 Hour
# 11     10K Operations
# 12             1 Hour
# 13             1 Hour
# 14             1 Hour
# 15      1M Operations
# 16             1 Hour
# 17             1 Hour
# 18     10K Operations
# 19             1 Hour
# 20               1 GB
# 21        Daily Units
# 22     100 Operations
# 23              Hours
# 24     10K Operations
# 25              Hours
# 26             1 Hour
# 27              Hours
# 28              Units
# 29              Units
# ...               ...
# 30961      1 GB/Month
# 30962          1 Hour
# 30963          1 Hour
# 30964          1 Hour
# 30965          1 Hour
# 30966           Hours
# 30967          1 Hour
# 30968  10K Operations
# 30969           Hours
# 30970          1 Hour
# 30971          1 Hour
# 30972          1 Hour
# 30973          1 Hour
# 30974          1 Hour
# 30975          1 Hour
# 30976           Hours
# 30977          1 Hour
# 30978          1 Hour
# 30979   1M Operations
# 30980              GB
# 30981          1 Hour
# 30982          1 Hour
# 30983           Hours
# 30984  10K Operations
# 30985  10K Operations
# 30986          1 Hour
# 30987      1 GB/Month
# 30988  10K Operations
# 30989           Units
# 30990          1 Hour
#
# [30991 rows x 11 columns]

# %%
uri_str = "{azure_mgmt_uri}/providers/Microsoft.Commerce/UsageAggregates?" + \
    "api-version=2015-06-01-preview&" + \
    "aggregationGranularity=Daily&" + \
    "reportedstartTime=2018-06-12+00%3a00%3a00Z&" + \
    "reportedEndTime=2018-06-14+00%3a00%3a00Z"
usage_url = uri_str.format(azure_mgmt_uri = azure_mgmt_uri)
usage_url
# Out:
# 'https://management.azure.com:443/subscriptions/3e6b71a1-1c47-4188-a4dc-793259a87549/providers/Microsoft.Commerce/UsageAggregates?api-version=2015-06-01-preview&aggregationGranularity=Daily&reportedstartTime=2018-06-12+00%3a00%3a00Z&reportedEndTime=2018-06-14+00%3a00%3a00Z'

# %%
response = requests.get(usage_url, allow_redirects=False, headers = {'Authorization': 'Bearer %s' %access_token})
usage = response.json()

# %%
# usage API doesn't return more than 1000 aggregates 
# see https://stackoverflow.com/questions/50948666/get-azurermconsumptionusagedetail-limited-response-to-1000-items
len(usage['value'])
# Out:
# 20

# %%
df_usage = pd.DataFrame.from_dict(usage['value'])
df_usage
# Out:
#                                                    id  \
# 0   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 1   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 2   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 3   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 4   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 5   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 6   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 7   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 8   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 9   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 10  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 11  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 12  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 13  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 14  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 15  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 16  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 17  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 18  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 19  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
#
#                          name  \
# 0   Daily_BRSDT_20180612_0000
# 1   Daily_BRSDT_20180612_0000
# 2   Daily_BRSDT_20180612_0000
# 3   Daily_BRSDT_20180612_0000
# 4   Daily_BRSDT_20180612_0000
# 5   Daily_BRSDT_20180612_0000
# 6   Daily_BRSDT_20180612_0000
# 7   Daily_BRSDT_20180612_0000
# 8   Daily_BRSDT_20180612_0000
# 9   Daily_BRSDT_20180612_0000
# 10  Daily_BRSDT_20180612_0000
# 11  Daily_BRSDT_20180612_0000
# 12  Daily_BRSDT_20180612_0000
# 13  Daily_BRSDT_20180612_0000
# 14  Daily_BRSDT_20180612_0000
# 15  Daily_BRSDT_20180612_0000
# 16  Daily_BRSDT_20180612_0000
# 17  Daily_BRSDT_20180612_0000
# 18  Daily_BRSDT_20180612_0000
# 19  Daily_BRSDT_20180612_0000
#
#                                            properties  \
# 0   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 1   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 2   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 3   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 4   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 5   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 6   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 7   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 8   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 9   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 10  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 11  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 12  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 13  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 14  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 15  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 16  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 17  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 18  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 19  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
#
#                                  type
# 0   Microsoft.Commerce/UsageAggregate
# 1   Microsoft.Commerce/UsageAggregate
# 2   Microsoft.Commerce/UsageAggregate
# 3   Microsoft.Commerce/UsageAggregate
# 4   Microsoft.Commerce/UsageAggregate
# 5   Microsoft.Commerce/UsageAggregate
# 6   Microsoft.Commerce/UsageAggregate
# 7   Microsoft.Commerce/UsageAggregate
# 8   Microsoft.Commerce/UsageAggregate
# 9   Microsoft.Commerce/UsageAggregate
# 10  Microsoft.Commerce/UsageAggregate
# 11  Microsoft.Commerce/UsageAggregate
# 12  Microsoft.Commerce/UsageAggregate
# 13  Microsoft.Commerce/UsageAggregate
# 14  Microsoft.Commerce/UsageAggregate
# 15  Microsoft.Commerce/UsageAggregate
# 16  Microsoft.Commerce/UsageAggregate
# 17  Microsoft.Commerce/UsageAggregate
# 18  Microsoft.Commerce/UsageAggregate
# 19  Microsoft.Commerce/UsageAggregate

# %%
# create a dataframe form the 'properties' key on each usage record
df_usage_detail = pd.DataFrame(df_usage['properties'].values.tolist())
df_usage_detail
# Out:
#    infoFields                                       instanceData  \
# 0          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 1          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 2          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 3          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 4          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 5          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 6          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 7          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 8          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 9          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 10         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 11         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 12         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 13         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 14         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 15         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 16         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 17         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 18         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 19         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
#
#        meterCategory                               meterId  \
# 0            Storage  e9549cbe-02d9-4213-b4be-22d6dfe8a3af
# 1    Data Management  9cb0bde8-bc0d-468c-8423-a25fe06779d3
# 2         Networking  9995d93a-7d35-4d3f-9c69-7a7fea447ef4
# 3   Virtual Machines  d101de3e-ae70-48bb-8605-64fcd0a3ce8f
# 4    Data Management  b9e5e77c-a0b3-4a2c-9b8b-57fa54f31c52
# 5         Networking  d54686f0-77ff-43f3-9e7c-2099030d32a7
# 6         Networking  f114cb19-ea64-40b5-bcd7-aee474b62853
# 7    Data Management  c80a3636-2edb-4248-bcb1-04ef818a75ac
# 8    Data Management  923978e1-fd3f-4bd5-a798-f4b533057e46
# 9         Networking  32c3ebec-1646-49e3-8127-2cafbd3a04d8
# 10   Data Management  40551b4c-e8be-48ed-b70b-f8d25c7de724
# 11        Networking  8f967c58-b144-4bd7-8882-8bf02767c839
# 12   Data Management  12da282f-7e96-49e2-983a-9a65da2a4866
# 13   Data Management  211e620c-ebcf-4db5-a7fd-996abebe9546
# 14   Data Management  42e2a22f-fabf-41ea-a21e-e86bb3ff5799
# 15   Data Management  b9e5e77c-a0b3-4a2c-9b8b-57fa54f31c52
# 16        Networking  d54686f0-77ff-43f3-9e7c-2099030d32a7
# 17        Networking  8f967c58-b144-4bd7-8882-8bf02767c839
# 18           Storage  e9549cbe-02d9-4213-b4be-22d6dfe8a3af
# 19           Storage  d23a5753-ff85-4ddf-af28-8cc5cf2d3882
#
#                                             meterName meterRegion  \
# 0             Premium Storage - Page Blob/P10 (Units)     US West
# 1   Standard IO - Table Write Operation Units (in ...         NaN
# 2                              Data Transfer Out (GB)      Zone 1
# 3                                        D4 v3/D4s v3     US West
# 4   Standard IO - Table Batch Write Operation Unit...         NaN
# 5                                    DNS Queries (1M)         NaN
# 6                                    IP Address Hours         NaN
# 7   Standard IO - Disk Write Operation Units (in 1...         NaN
# 8   Standard IO - Block Blob Delete Operation Unit...         NaN
# 9                               Data Transfer In (GB)      Zone 1
# 10  Standard IO - Block Blob Read Operation Units ...         NaN
# 11                                              Zones         NaN
# 12  Standard IO - Table Read Operation Units (in 1...         NaN
# 13  Standard IO - Block Blob Write Operation Units...         NaN
# 14  Standard IO - Disk Read Operation Units (in 10...         NaN
# 15  Standard IO - Table Batch Write Operation Unit...         NaN
# 16                                   DNS Queries (1M)         NaN
# 17                                              Zones         NaN
# 18            Premium Storage - Page Blob/P10 (Units)     US West
# 19                  Standard IO - Page Blob/Disk (GB)         NaN
#
#            meterSubCategory  quantity                        subscriptionId  \
# 0         Locally Redundant  0.001389  3e6b71a1-1c47-4188-a4dc-793259a87549
# 1                       NaN  0.000500  3e6b71a1-1c47-4188-a4dc-793259a87549
# 2                       NaN  0.059841  3e6b71a1-1c47-4188-a4dc-793259a87549
# 3   Dv3/DSv3 Series Windows  0.766682  3e6b71a1-1c47-4188-a4dc-793259a87549
# 4                       NaN  0.000100  3e6b71a1-1c47-4188-a4dc-793259a87549
# 5                       DNS  0.000804  3e6b71a1-1c47-4188-a4dc-793259a87549
# 6       Public IP Addresses  0.900000  3e6b71a1-1c47-4188-a4dc-793259a87549
# 7                       NaN  0.009300  3e6b71a1-1c47-4188-a4dc-793259a87549
# 8                       NaN  0.004500  3e6b71a1-1c47-4188-a4dc-793259a87549
# 9                       NaN  1.619603  3e6b71a1-1c47-4188-a4dc-793259a87549
# 10                      NaN  0.058600  3e6b71a1-1c47-4188-a4dc-793259a87549
# 11                      DNS  0.013441  3e6b71a1-1c47-4188-a4dc-793259a87549
# 12                      NaN  0.000500  3e6b71a1-1c47-4188-a4dc-793259a87549
# 13                      NaN  0.004900  3e6b71a1-1c47-4188-a4dc-793259a87549
# 14                      NaN  0.009600  3e6b71a1-1c47-4188-a4dc-793259a87549
# 15                      NaN  0.014400  3e6b71a1-1c47-4188-a4dc-793259a87549
# 16                      DNS  0.000694  3e6b71a1-1c47-4188-a4dc-793259a87549
# 17                      DNS  0.032258  3e6b71a1-1c47-4188-a4dc-793259a87549
# 18        Locally Redundant  0.033336  3e6b71a1-1c47-4188-a4dc-793259a87549
# 19        Locally Redundant  0.000006  3e6b71a1-1c47-4188-a4dc-793259a87549
#
#           unit               usageEndTime             usageStartTime
# 0        Units  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 1      10,000s  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 2           GB  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 3       1 Hour  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 4      10,000s  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 5   1M Queries  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 6        Hours  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 7      10,000s  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 8      10,000s  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 9           GB  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 10     10,000s  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 11   DNS Zones  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 12     10,000s  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 13     10,000s  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 14     10,000s  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 15     10,000s  2018-06-14T00:00:00+00:00  2018-06-13T00:00:00+00:00
# 16  1M Queries  2018-06-14T00:00:00+00:00  2018-06-13T00:00:00+00:00
# 17   DNS Zones  2018-06-14T00:00:00+00:00  2018-06-13T00:00:00+00:00
# 18       Units  2018-06-14T00:00:00+00:00  2018-06-13T00:00:00+00:00
# 19          GB  2018-06-14T00:00:00+00:00  2018-06-13T00:00:00+00:00

# %%
# https://msdn.microsoft.com/en-us/library/azure/mt219001.aspx
# Note the query is by *reported* time, but the return is by *usage* time
# "... we ask callers to query by Reported Time to ensure that they get all the usage 
# events reported within a specific time period within the billing system. Even though the query is made 
# with the Reported Time, the usage response is aggregated by the resource usage time, which is the useful 
# pivot for callers."
# We queried from 6-12 to 6-14. This usage shows up on 6-12 to 6-13, but if you quesry
# 6-12 to 6-13 this record will not be picked up as it was *reported* 6-13 to 6-14

df_usage_detail.loc[df_usage_detail['meterId'] == "9995d93a-7d35-4d3f-9c69-7a7fea447ef4"]
# Out:
#   infoFields                                       instanceData meterCategory  \
# 2         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...    Networking
#
#                                 meterId               meterName meterRegion  \
# 2  9995d93a-7d35-4d3f-9c69-7a7fea447ef4  Data Transfer Out (GB)      Zone 1
#
#   meterSubCategory  quantity                        subscriptionId unit  \
# 2              NaN  0.059841  3e6b71a1-1c47-4188-a4dc-793259a87549   GB
#
#                 usageEndTime             usageStartTime
# 2  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00

# %%
invoice_list_url = "https://management.azure.com:443/subscriptions/{subscriptionId}/providers/Microsoft.Billing/invoices?api-version=2017-04-24-preview".format(subscriptionId = subscription)
invoice_list_url
# Out:
# 'https://management.azure.com:443/subscriptions/3e6b71a1-1c47-4188-a4dc-793259a87549/providers/Microsoft.Billing/invoices?api-version=2017-04-24-preview'

# %%
response = requests.get(invoice_list_url, allow_redirects=False, headers = {'Authorization': 'Bearer %s' %access_token})

# %%
# There are 3 invoices against this subscription so far
response.json()
# Out:
# {'value': [{'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc-793259a87549/providers/Microsoft.Billing/invoices/201810-318387190656310',
#    'type': 'Microsoft.Billing/invoices',
#    'name': '201810-318387190656310',
#    'properties': {'invoicePeriodEndDate': '2018-09-11',
#     'invoicePeriodStartDate': '2018-08-12',
#     'billingPeriodIds': ['/subscriptions/3e6b71a1-1c47-4188-a4dc-793259a87549/providers/Microsoft.Billing/billingPeriods/201810-1']}},
#   {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc-793259a87549/providers/Microsoft.Billing/invoices/201809-318692150622116',
#    'type': 'Microsoft.Billing/invoices',
#    'name': '201809-318692150622116',
#    'properties': {'invoicePeriodEndDate': '2018-08-11',
#     'invoicePeriodStartDate': '2018-07-12',
#     'billingPeriodIds': ['/subscriptions/3e6b71a1-1c47-4188-a4dc-793259a87549/providers/Microsoft.Billing/billingPeriods/201809-1']}},
#   {'id': '/subscriptions/3e6b71a1-1c47-4188-a4dc-793259a87549/providers/Microsoft.Billing/invoices/201808-318222150603647',
#    'type': 'Microsoft.Billing/invoices',
#    'name': '201808-318222150603647',
#    'properties': {'invoicePeriodEndDate': '2018-07-11',
#     'invoicePeriodStartDate': '2018-06-12',
#     'billingPeriodIds': ['/subscriptions/3e6b71a1-1c47-4188-a4dc-793259a87549/providers/Microsoft.Billing/billingPeriods/201808-1']}}]}

# %%
invoice_name = response.json()['value'][0]['name']
invoice_name
# Out:
# '201810-318387190656310'

# %%
invoice_url = "https://management.azure.com:443/subscriptions/{subscriptionId}/providers/Microsoft.Billing/invoices/{invoiceName}?api-version=2017-04-24-preview".format(subscriptionId = subscription, invoiceName=invoice_name)

# %%
# download invoice pdf
response = requests.get(invoice_url, allow_redirects=False, headers = {'Authorization': 'Bearer %s' %access_token})

# %%
invoice_pdf_url = response.json()['properties']['downloadUrl']['url']

# %%
response = requests.get(invoice_pdf_url)

# %%
f = open('invoice.pdf', 'wb')
f.write(response.content)
f.close()

# %%
# !open invoice.pdf

# %%
# pickle everything
import pickle
pickle.dump( df_usage, open( "df_usage.p", "wb" ) )
pickle.dump( df_rates, open( "df_rates.p", "wb" ) )
pickle.dump( df_usage_detail, open( "df_usage_detail.p", "wb" ) )

# %%
# TODO
# aggregate usage on rate
# left join usage on rates
# iter 
#   process row into rated record
