# %%
import adal
from msrestazure.azure_active_directory import AADTokenCredentials
from dotenv import load_dotenv, find_dotenv
import os
load_dotenv(find_dotenv())
# Out:
# True

# %%
import requests
 
# Parameters need for API
subscription = os.getenv("SUBSCRIPTION")
tenant = os.getenv("TENANT")
client_id = os.getenv("CLIENT_ID")
client_secret = os.getenv("CLIENT_SECRET")
offer = 'MS-AZR-0003P'
currency = 'USD'
locale = 'en-US'
region = 'US'

# %%
def authenticate_client_key(tenant, client_id, client_secret):
    """
    Authenticate using service principal w/ key.
    """
    authority_host_uri = 'https://login.microsoftonline.com'
    authority_uri = authority_host_uri + '/' + tenant
    resource_uri = 'https://management.core.windows.net/'
    
    context = adal.AuthenticationContext(authority_uri, api_version=None)
    mgmt_token = context.acquire_token_with_client_credentials(resource_uri, client_id, client_secret)
    credentials = AADTokenCredentials(mgmt_token, client_id)

    return credentials

# %%
credentials = authenticate_client_key(tenant, client_id, client_secret)
access_token = credentials.token.get('access_token')

# %%
azure_mgmt_uri = 'https://management.azure.com:443/subscriptions/{subscriptionId}'.format(subscriptionId = subscription)

# %%
# Azure Resource RateCard API 
# https://docs.microsoft.com/en-us/azure/billing/billing-usage-rate-card-overview
uri_str = "{azure_mgmt_uri}/providers/Microsoft.Commerce/RateCard?" + \
    "api-version=2016-08-31-preview&$filter=OfferDurableId eq '{offerId}' and " + \
    "Currency eq '{currencyId}' and Locale eq '{localeId}' and RegionInfo eq '{regionId}'"
    
rateCardUrl = uri_str.format(
    azure_mgmt_uri = azure_mgmt_uri,
    offerId = offer, 
    currencyId = currency, 
    localeId = locale, 
    regionId = region)

# Don't allow redirects and call the RateCard API
response = requests.get(rateCardUrl, allow_redirects=False, headers = {'Authorization': 'Bearer %s' %access_token})

# Look at response headers to get the redirect URL
redirectUrl = response.headers['Location']

# Get the ratecard content by making another call to go the redirect URL
rateCard = requests.get(redirectUrl)

# %%
import pandas as pd
import json

# %%
r = json.loads(rateCard.content.decode("utf-8"))
df_rates = pd.DataFrame.from_dict(r['Meters'])
df_rates
# Out:
#               EffectiveDate  IncludedQuantity                  MeterCategory  \
# 0      2017-04-01T00:00:00Z               0.0               Virtual Machines
# 1      2017-02-01T00:00:00Z               0.0                  Data Services
# 2      2014-05-01T00:00:00Z               0.0               Virtual Machines
# 3      2017-10-20T00:00:00Z               0.0                 Cloud Services
# 4      2016-02-01T00:00:00Z               0.0                 Cloud Services
# 5      2016-02-01T00:00:00Z               0.0                 Cloud Services
# 6      2017-01-01T00:00:00Z               0.0                        Storage
# 7      2016-09-01T00:00:00Z               0.0             SQL Data Warehouse
# 8      2017-11-03T00:00:00Z               0.0                 Cloud Services
# 9      2017-04-01T00:00:00Z               0.0               Virtual Machines
# 10     2017-11-03T00:00:00Z               0.0               Virtual Machines
# 11     2018-05-01T00:00:00Z               0.0  Azure Database for PostgreSQL
# 12     2018-02-28T00:00:00Z               0.0               Virtual Machines
# 13     2017-07-21T00:00:00Z               0.0               Virtual Machines
# 14     2018-02-28T00:00:00Z               0.0               Virtual Machines
# 15     2017-12-15T00:00:00Z               0.0                   App Services
# 16     2016-10-01T00:00:00Z               0.0             Cognitive Services
# 17     2017-02-01T00:00:00Z               0.0                 Cloud Services
# 18     2017-02-01T00:00:00Z               0.0                 Cloud Services
# 19     2018-02-14T00:00:00Z               0.0                 Cloud Services
# 20     2017-07-21T00:00:00Z               0.0                 Cloud Services
# 21     2017-10-01T00:00:00Z               0.0                        Storage
# 22     2015-06-01T00:00:00Z               0.0                        Storage
# 23     2017-12-01T00:00:00Z               0.0               Virtual Machines
# 24     2018-05-01T00:00:00Z               0.0  Azure Database for PostgreSQL
# 25     2016-02-01T00:00:00Z               0.0                 Cloud Services
# 26     2016-09-07T00:00:00Z               0.0                  Data Services
# 27     2018-04-27T00:00:00Z               0.0               Virtual Machines
# 28     2017-02-01T00:00:00Z               0.0               Virtual Machines
# 29     2018-04-27T00:00:00Z               0.0               Virtual Machines
# ...                     ...               ...                            ...
# 27762  2017-10-03T00:00:00Z               0.0                  Data Services
# 27763  2016-11-01T00:00:00Z               0.0               Virtual Machines
# 27764  2018-02-28T00:00:00Z               0.0               Virtual Machines
# 27765  2018-02-14T00:00:00Z               0.0               Virtual Machines
# 27766  2017-12-15T00:00:00Z               0.0                 Cloud Services
# 27767  2017-12-01T00:00:00Z               0.0               Virtual Machines
# 27768  2017-08-01T00:00:00Z               0.0                        Storage
# 27769  2017-11-03T00:00:00Z               0.0                 Cloud Services
# 27770  2017-11-03T00:00:00Z               0.0               Virtual Machines
# 27771  2017-11-03T00:00:00Z               0.0               Virtual Machines
# 27772  2017-08-18T00:00:00Z               0.0               Virtual Machines
# 27773  2017-04-01T00:00:00Z               0.0               Virtual Machines
# 27774  2018-05-11T00:00:00Z               0.0               Virtual Machines
# 27775  2017-03-01T00:00:00Z               0.0               Virtual Machines
# 27776  2014-12-01T00:00:00Z               0.0                 Cloud Services
# 27777  2018-04-27T00:00:00Z               0.0               Virtual Machines
# 27778  2017-04-01T00:00:00Z               0.0               Virtual Machines
# 27779  2017-09-19T00:00:00Z               0.0                  Data Services
# 27780  2016-02-22T00:00:00Z               0.0                Data Management
# 27781  2018-04-27T00:00:00Z               0.0               Virtual Machines
# 27782  2017-08-18T00:00:00Z               0.0               Virtual Machines
# 27783  2017-11-03T00:00:00Z               0.0               Virtual Machines
# 27784  2016-07-01T00:00:00Z               0.0               Virtual Machines
# 27785  2018-05-11T00:00:00Z               0.0                        Storage
# 27786  2018-03-28T00:00:00Z               0.0                        Storage
# 27787  2018-02-28T00:00:00Z               0.0                   SQL Database
# 27788  2018-02-28T00:00:00Z               0.0                   SQL Database
# 27789  2018-06-01T00:00:00Z               0.0                        Storage
# 27790  2017-10-01T00:00:00Z               0.0                        Storage
# 27791  2017-11-03T00:00:00Z               0.0               Virtual Machines
#
#                                     MeterId  \
# 0      d0bf9053-17c4-4fec-8502-4eb8376343a7
# 1      8b7672d4-16fc-446e-9935-cf2223c5290f
# 2      2c4db260-4bc7-4388-a42f-b0c709255ae8
# 3      c9c058cb-822e-46ae-86fb-6b583f91b4b5
# 4      0aaf975b-8e33-404b-93f7-de7d69774ca1
# 5      77860eb6-e2bc-4d06-8efe-491d840adaf5
# 6      8ebaf4a8-960b-457b-ba6b-70b59c959ec7
# 7      22e690b0-183e-4266-bbeb-0c8ccf98f160
# 8      1c389e44-fc99-46dd-93b4-5aab8f611ccc
# 9      241669f0-6b85-49a2-9bb1-dbe4996f38e8
# 10     1dfddd5d-9ff3-4880-825f-e8f4e677d981
# 11     fa22482b-bdf3-4096-91f4-cc163a73067f
# 12     d1ff3c06-f95c-44db-a35b-5fec56696cfe
# 13     5a94d716-e0af-46da-8be7-cd0ff915048d
# 14     f5730a2a-2d31-4e78-b70e-4b8c88c46236
# 15     aa807928-96d4-4f53-a978-5372b81a4f89
# 16     2a9b16cf-2b54-4f0a-93ca-232f83502b7b
# 17     1b785b8a-c818-4131-aa73-31d59f6b5a3f
# 18     7c901a8a-4979-4a7a-afac-3d49a0f6fc22
# 19     37103b93-94f0-4093-b204-04d8cb36b0e4
# 20     1a63414f-7ce3-4298-875b-5f324434c159
# 21     e86146db-e868-41bf-a1dd-98c927abf13d
# 22     c069fd89-c3ce-4caa-b018-0bc26dd0a6a9
# 23     6d65be7f-3a02-460e-a11f-2a574739e617
# 24     a93b0072-20e9-4476-a758-2e40031c1d14
# 25     2eaa171a-68e4-489d-a914-54489cb2ab9f
# 26     05d8cdf9-3a31-49a1-aa63-fe4d01c686dd
# 27     feffa92d-af64-4844-bbe2-d4085b38bc93
# 28     cbfefcf0-45c1-448b-a02f-87772697cb78
# 29     3de76938-0510-4043-98d8-24eeed51578d
# ...                                     ...
# 27762  9fcf66b8-4210-49b0-b494-3317382bc6cc
# 27763  5c54154b-efc5-44d3-b55c-51cd4b08d710
# 27764  0bff0482-5bd0-4dfe-a77b-044755d65a9f
# 27765  24a4176b-caeb-487b-ae30-a1a57df37154
# 27766  323ca957-eea0-4e0a-9a92-ab9b620eb98c
# 27767  e4a5968d-fb1e-48b7-9520-d3150c714363
# 27768  f6bfb57a-4154-46c3-9d13-53fe4e529699
# 27769  03c2aeaa-b8aa-4bba-b3d6-80ee261967f9
# 27770  a378127f-ac54-431c-89ec-9b880de980ed
# 27771  12c1a277-5baa-46af-8438-794269f83ecc
# 27772  0f42cb3c-4bb2-4ead-bfac-687f6bb7f730
# 27773  768ff130-a8a1-49c1-9506-fe3fe5b29051
# 27774  d2ce791a-13cc-4999-8d4d-a15b860fc72b
# 27775  028967ae-4f16-4e72-b78d-c8a4314e40a1
# 27776  95b38082-a0db-474c-9fca-5650c639fb9b
# 27777  97cfd790-7525-47e8-8e5c-0a3722203443
# 27778  ddfbab12-75cd-4986-a872-800234e50209
# 27779  382d49a4-3d9b-45ea-bf9d-a19a79171d72
# 27780  13553d04-5057-4557-872b-cafaf85e256a
# 27781  94694ba0-f9ac-49dd-ac7d-0060b9904f8e
# 27782  a0716d5a-2c14-4fae-8ed1-d52b9812e329
# 27783  47baac53-00f2-48ef-a35e-f7227c0eb130
# 27784  70653a90-aede-4e59-a122-265a80801f27
# 27785  7fe704d0-2144-4b35-854a-78fd64bbc9e6
# 27786  a3cd5202-563a-4b0d-9d58-0ad494c62215
# 27787  644a585e-7cac-4264-8be5-8e458e92ba00
# 27788  9da7ff6e-a685-4b36-9f9d-48fcbd3f220c
# 27789  51fd764c-2df2-4aa4-a240-0c271e846e26
# 27790  e2f7a370-4a77-478b-b258-85677c2041bf
# 27791  78ee8f2c-813d-40b2-ad80-8df9c56c7920
#
#                                          MeterName        MeterRates  \
# 0                                    Compute Hours      {'0': 0.077}
# 1              Standard S3 Secondary Database Days     {'0': 4.0177}
# 2                                    Compute Hours       {'0': 0.64}
# 3                                    Compute Hours      {'0': 4.676}
# 4                                    Compute Hours       {'0': 0.14}
# 5                                    Compute Hours      {'0': 3.518}
# 6          Premium Storage - Page Blob/P60 (Units)     {'0': 946.08}
# 7                                          100 DWU     {'0': 1.5121}
# 8                                    Compute Hours       {'0': 3.04}
# 9                                    Compute Hours      {'0': 0.183}
# 10                                   Compute Hours      {'0': 0.598}
# 11                                           vCore     {'0': 0.0408}
# 12                                   Compute Hours     {'0': 0.1475}
# 13                                   Compute Hours      {'0': 0.248}
# 14                                   Compute Hours       {'0': 0.35}
# 15                    Log Analytics Data Retention       {'0': 0.14}
# 16                                S2 (Daily Units)  {'0': 22.580645}
# 17                                   Compute Hours     {'0': 0.3638}
# 18                                   Compute Hours      {'0': 1.525}
# 19                                   Compute Hours       {'0': 7.08}
# 20                                   Compute Hours      {'0': 1.672}
# 21               Standard Managed Disk/S15 (Units)    {'0': 12.4608}
# 22         Premium Storage - Page Blob/P10 (Units)      {'0': 20.61}
# 23                                   Compute Hours     {'0': 0.0928}
# 24                                          2vCore     {'0': 0.0816}
# 25                                   Compute Hours      {'0': 1.173}
# 26                          Basic Elastic DTU Pack      {'0': 0.061}
# 27                                   Compute Hours      {'0': 8.359}
# 28                                   Compute Hours      {'0': 0.545}
# 29                                   Compute Hours     {'0': 1.4616}
# ...                                            ...               ...
# 27762                     Gen Pur vCore ReadRep G4    {'0': 0.06475}
# 27763                                Compute Hours      {'0': 0.225}
# 27764                                Compute Hours       {'0': 0.08}
# 27765                                Compute Hours    {'0': 0.13875}
# 27766                                Compute Hours      {'0': 3.008}
# 27767                                Compute Hours     {'0': 0.0564}
# 27768  GPv2 Std IO - Page Blob Read Addtl IO Units    {'0': 0.00017}
# 27769                                Compute Hours      {'0': 9.613}
# 27770                                Compute Hours      {'0': 0.011}
# 27771                                Compute Hours      {'0': 0.074}
# 27772                                Compute Hours      {'0': 1.867}
# 27773                                Compute Hours      {'0': 0.528}
# 27774                                Compute Hours       {'0': 1.01}
# 27775                                Compute Hours      {'0': 0.044}
# 27776                                Compute Hours       {'0': 0.64}
# 27777                                Compute Hours     {'0': 5.8463}
# 27778                                Compute Hours        {'0': 1.4}
# 27779                                   MI IO Rate       {'0': 0.11}
# 27780            Geo-Replicated Data Transfer (GB)       {'0': 0.16}
# 27781                                Compute Hours     {'0': 3.7476}
# 27782                                Compute Hours      {'0': 0.026}
# 27783                                Compute Hours      {'0': 3.469}
# 27784                                Compute Hours        {'0': 9.0}
# 27785        GPv2 Std IO - File Protocol Ops Units     {'0': 0.0015}
# 27786                      Cool Read Additional IO     {'0': 0.0025}
# 27787                                        vCore   {'0': 0.365322}
# 27788                                  Data Stored    {'0': 0.15525}
# 27789        GPv2 Std IO - Queue Class 1 Ops Units      {'0': 0.004}
# 27790             Standard Managed Disk/S6 (Units)     {'0': 4.8128}
# 27791                                Compute Hours      {'0': 0.152}
#
#             MeterRegion MeterStatus  \
# 0             US West 2      Active
# 1              KR South      Active
# 2          AP Southeast      Active
# 3               AU East      Active
# 4               US West      Active
# 5               AP East      Active
# 6               US West      Active
# 7            US Central      Active
# 8               JA West      Active
# 9              BR South      Active
# 10         AP Southeast      Active
# 11     US South Central      Active
# 12         AU Central 2      Active
# 13           FR Central      Active
# 14         AU Central 2      Active
# 15             KR South      Active
# 16                           Active
# 17            US Gov TX      Active
# 18            US Gov TX      Active
# 19             UK South      Active
# 20              US West      Active
# 21           IN Central      Active
# 22              JA West      Active
# 23              AU East      Active
# 24           US Central      Active
# 25              US West      Active
# 26             UK South      Active
# 27              US East      Active
# 28            US Gov AZ      Active
# 29              AU East      Active
# ...                 ...         ...
# 27762      AP Southeast      Active
# 27763           AU East      Active
# 27764      AU Central 2      Active
# 27765        AU Central      Active
# 27766         US West 2      Active
# 27767          IN South      Active
# 27768           JA West      Active
# 27769           US East      Active
# 27770           IN West      Active
# 27771        KR Central      Active
# 27772           EU West      Active
# 27773           US West      Active
# 27774        KR Central      Active
# 27775         US West 2      Active
# 27776        US Central      Active
# 27777           AU East      Active
# 27778           JA East      Active
# 27779           IN West      Active
# 27780          BR South      Active
# 27781         US Gov AZ      Active
# 27782           CA East      Active
# 27783         US West 2      Active
# 27784                        Active
# 27785           US East      Active
# 27786        AU Central      Active
# 27787        US Central      Active
# 27788        KR Central      Active
# 27789        FR Central      Active
# 27790           AU East      Active
# 27791           IN West      Active
#
#                                         MeterSubCategory MeterTags  \
# 0                  Standard_F2 VM Low Priority (Windows)        []
# 1                                           SQL Database        []
# 2                                        A6 VM (Windows)        []
# 3              Standard_H16r Cloud Services Low Priority        []
# 4                          Standard_D1_v2 Cloud Services        []
# 5                         Standard_D15_v2 Cloud Services        []
# 6                                      Locally Redundant        []
# 7                                 Compute Optimized Gen1        []
# 8            Standard_E64_v3 Cloud Services Low Priority        []
# 9                        Standard_A8m_v2 VM Low Priority        []
# 10                          Standard_L32 VM Low Priority        []
# 11                                    Basic Compute Gen5        []
# 12              Standard_D2_v2 VM Low Priority (Windows)        []
# 13                           Standard_E2_v3 VM (Windows)        []
# 14              Standard_A8_v2 VM Low Priority (Windows)        []
# 15                                                              []
# 16                                    Custom Recognition        []
# 17                        Standard_D11_v2 Cloud Services        []
# 18                            Standard_G2 Cloud Services        []
# 19                        Standard_F64_v2 Cloud Services        []
# 20                        Standard_D16_v3 Cloud Services        []
# 21                                     Locally Redundant        []
# 22                                     Locally Redundant        []
# 23                              BASIC.A4 VM Low Priority        []
# 24                                    Basic Compute Gen4        []
# 25                        Standard_D13_v2 Cloud Services        []
# 26                                          SQL Database        []
# 27                           Standard_M64ls VM (Windows)        []
# 28                                       A6 VM (Windows)        []
# 29               Standard_M8ms VM Low Priority (Windows)        []
# ...                                                  ...       ...
# 27762                           Azure Database for MySQL        []
# 27763                       Standard_A2m_v2 VM (Windows)        []
# 27764                                     Standard_B2 VM        []
# 27765                                 A6 VM Low Priority        []
# 27766                     Standard_D32_v3 Cloud Services        []
# 27767                 BASIC.A2 VM Low Priority (Windows)        []
# 27768                                                           []
# 27769                       Standard_M64s Cloud Services        []
# 27770                        Standard_F1 VM Low Priority        []
# 27771              Standard_F2 VM Low Priority (Windows)        []
# 27772                      Standard_M64s VM Low Priority        []
# 27773                           Standard_L4 VM (Windows)        []
# 27774          Standard_E20_v3 VM Low Priority (Windows)        []
# 27775                                 A5 VM Low Priority        []
# 27776                                  A4 Cloud Services        []
# 27777           Standard_M32ms VM Low Priority (Windows)        []
# 27778                     Standard_NC24r VM Low Priority        []
# 27779                                       SQL Database        []
# 27780                                                           []
# 27781                       Standard_MDB16s VM (Windows)        []
# 27782                                    Standard_B1m VM        []
# 27783         Standard_NC24_v2 VM Low Priority (Windows)        []
# 27784                    SQL Server Enterprise (24 core)        []
# 27785                                     Zone Redundant        []
# 27786        Azure Data Lake Storage Gen2 Flat Namespace        []
# 27787  Single/Elastic Pool Business Critical - Comput...        []
# 27788      Single/Elastic Pool General Purpose - Storage        []
# 27789                                     Zone Redundant        []
# 27790                                  Locally Redundant        []
# 27791                    Standard_D13_v2 VM Low Priority        []
#
#                  Unit
# 0               Hours
# 1                Days
# 2               Hours
# 3              1 Hour
# 4               Hours
# 5               Hours
# 6               Units
# 7               Hours
# 8              1 Hour
# 9               Hours
# 10              Hours
# 11             1 Hour
# 12              Hours
# 13              Hours
# 14              Hours
# 15               1 GB
# 16        Daily Units
# 17              Hours
# 18              Hours
# 19             1 Hour
# 20              Hours
# 21              Units
# 22              Units
# 23             1 Hour
# 24             1 Hour
# 25              Hours
# 26               Days
# 27             1 Hour
# 28              Hours
# 29             1 Hour
# ...               ...
# 27762          1 Hour
# 27763           Hours
# 27764          1 Hour
# 27765           Hours
# 27766           Hours
# 27767          1 Hour
# 27768  10K Operations
# 27769           Hours
# 27770           Hours
# 27771           Hours
# 27772          1 Hour
# 27773          1 Hour
# 27774          1 Hour
# 27775           Hours
# 27776           Hours
# 27777          1 Hour
# 27778           Hours
# 27779   1M Operations
# 27780              GB
# 27781          1 Hour
# 27782          1 Hour
# 27783          1 Hour
# 27784           Hours
# 27785  10K Operations
# 27786  10K Operations
# 27787          1 Hour
# 27788      1 GB/Month
# 27789  10K Operations
# 27790           Units
# 27791           Hours
#
# [27792 rows x 11 columns]

# %%
uri_str = "{azure_mgmt_uri}/providers/Microsoft.Commerce/UsageAggregates?" + \
    "api-version=2015-06-01-preview&" + \
    "aggregationGranularity=Daily&" + \
    "reportedstartTime=2018-06-12+00%3a00%3a00Z&" + \
    "reportedEndTime=2018-06-14+00%3a00%3a00Z"
usage_url = uri_str.format(azure_mgmt_uri = azure_mgmt_uri)
usage_url
# Out:
# 'https://management.azure.com:443/subscriptions/3e6b71a1-1c47-4188-a4dc-793259a87549/providers/Microsoft.Commerce/UsageAggregates?api-version=2015-06-01-preview&aggregationGranularity=Daily&reportedstartTime=2018-06-12+00%3a00%3a00Z&reportedEndTime=2018-06-14+00%3a00%3a00Z'

# %%
response = requests.get(usage_url, allow_redirects=False, headers = {'Authorization': 'Bearer %s' %access_token})
usage = response.json()

# %%
# usage API doesn't return more than 1000 aggregates 
# see https://stackoverflow.com/questions/50948666/get-azurermconsumptionusagedetail-limited-response-to-1000-items
len(usage['value'])
# Out:
# 20

# %%
df_usage = pd.DataFrame.from_dict(usage['value'])
df_usage
# Out:
#                                                    id  \
# 0   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 1   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 2   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 3   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 4   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 5   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 6   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 7   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 8   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 9   /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 10  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 11  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 12  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 13  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 14  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 15  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 16  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 17  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 18  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
# 19  /subscriptions/3e6b71a1-1c47-4188-a4dc-793259a...
#
#                          name  \
# 0   Daily_BRSDT_20180612_0000
# 1   Daily_BRSDT_20180612_0000
# 2   Daily_BRSDT_20180612_0000
# 3   Daily_BRSDT_20180612_0000
# 4   Daily_BRSDT_20180612_0000
# 5   Daily_BRSDT_20180612_0000
# 6   Daily_BRSDT_20180612_0000
# 7   Daily_BRSDT_20180612_0000
# 8   Daily_BRSDT_20180612_0000
# 9   Daily_BRSDT_20180612_0000
# 10  Daily_BRSDT_20180612_0000
# 11  Daily_BRSDT_20180612_0000
# 12  Daily_BRSDT_20180612_0000
# 13  Daily_BRSDT_20180612_0000
# 14  Daily_BRSDT_20180612_0000
# 15  Daily_BRSDT_20180612_0000
# 16  Daily_BRSDT_20180612_0000
# 17  Daily_BRSDT_20180612_0000
# 18  Daily_BRSDT_20180612_0000
# 19  Daily_BRSDT_20180612_0000
#
#                                            properties  \
# 0   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 1   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 2   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 3   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 4   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 5   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 6   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 7   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 8   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 9   {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 10  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 11  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 12  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 13  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 14  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 15  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 16  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 17  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 18  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
# 19  {'subscriptionId': '3e6b71a1-1c47-4188-a4dc-79...
#
#                                  type
# 0   Microsoft.Commerce/UsageAggregate
# 1   Microsoft.Commerce/UsageAggregate
# 2   Microsoft.Commerce/UsageAggregate
# 3   Microsoft.Commerce/UsageAggregate
# 4   Microsoft.Commerce/UsageAggregate
# 5   Microsoft.Commerce/UsageAggregate
# 6   Microsoft.Commerce/UsageAggregate
# 7   Microsoft.Commerce/UsageAggregate
# 8   Microsoft.Commerce/UsageAggregate
# 9   Microsoft.Commerce/UsageAggregate
# 10  Microsoft.Commerce/UsageAggregate
# 11  Microsoft.Commerce/UsageAggregate
# 12  Microsoft.Commerce/UsageAggregate
# 13  Microsoft.Commerce/UsageAggregate
# 14  Microsoft.Commerce/UsageAggregate
# 15  Microsoft.Commerce/UsageAggregate
# 16  Microsoft.Commerce/UsageAggregate
# 17  Microsoft.Commerce/UsageAggregate
# 18  Microsoft.Commerce/UsageAggregate
# 19  Microsoft.Commerce/UsageAggregate

# %%
# create a dataframe form the 'properties' key on each usage record
df_usage_detail = pd.DataFrame(df_usage['properties'].values.tolist())
df_usage_detail
# Out:
#    infoFields                                       instanceData  \
# 0          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 1          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 2          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 3          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 4          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 5          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 6          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 7          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 8          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 9          {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 10         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 11         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 12         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 13         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 14         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 15         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 16         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 17         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 18         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
# 19         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...
#
#        meterCategory                               meterId  \
# 0            Storage  e9549cbe-02d9-4213-b4be-22d6dfe8a3af
# 1    Data Management  9cb0bde8-bc0d-468c-8423-a25fe06779d3
# 2         Networking  9995d93a-7d35-4d3f-9c69-7a7fea447ef4
# 3   Virtual Machines  d101de3e-ae70-48bb-8605-64fcd0a3ce8f
# 4    Data Management  b9e5e77c-a0b3-4a2c-9b8b-57fa54f31c52
# 5         Networking  d54686f0-77ff-43f3-9e7c-2099030d32a7
# 6         Networking  f114cb19-ea64-40b5-bcd7-aee474b62853
# 7    Data Management  c80a3636-2edb-4248-bcb1-04ef818a75ac
# 8    Data Management  923978e1-fd3f-4bd5-a798-f4b533057e46
# 9         Networking  32c3ebec-1646-49e3-8127-2cafbd3a04d8
# 10   Data Management  40551b4c-e8be-48ed-b70b-f8d25c7de724
# 11        Networking  8f967c58-b144-4bd7-8882-8bf02767c839
# 12   Data Management  12da282f-7e96-49e2-983a-9a65da2a4866
# 13   Data Management  211e620c-ebcf-4db5-a7fd-996abebe9546
# 14   Data Management  42e2a22f-fabf-41ea-a21e-e86bb3ff5799
# 15   Data Management  b9e5e77c-a0b3-4a2c-9b8b-57fa54f31c52
# 16        Networking  d54686f0-77ff-43f3-9e7c-2099030d32a7
# 17        Networking  8f967c58-b144-4bd7-8882-8bf02767c839
# 18           Storage  e9549cbe-02d9-4213-b4be-22d6dfe8a3af
# 19           Storage  d23a5753-ff85-4ddf-af28-8cc5cf2d3882
#
#                                             meterName meterRegion  \
# 0             Premium Storage - Page Blob/P10 (Units)     US West
# 1   Standard IO - Table Write Operation Units (in ...         NaN
# 2                              Data Transfer Out (GB)      Zone 1
# 3                                       Compute Hours     US West
# 4   Standard IO - Table Batch Write Operation Unit...         NaN
# 5                                    DNS Queries (1M)         NaN
# 6                                    IP Address Hours         NaN
# 7   Standard IO - Disk Write Operation Units (in 1...         NaN
# 8   Standard IO - Block Blob Delete Operation Unit...         NaN
# 9                               Data Transfer In (GB)      Zone 1
# 10  Standard IO - Block Blob Read Operation Units ...         NaN
# 11                                              Zones         NaN
# 12  Standard IO - Table Read Operation Units (in 1...         NaN
# 13  Standard IO - Block Blob Write Operation Units...         NaN
# 14  Standard IO - Disk Read Operation Units (in 10...         NaN
# 15  Standard IO - Table Batch Write Operation Unit...         NaN
# 16                                   DNS Queries (1M)         NaN
# 17                                              Zones         NaN
# 18            Premium Storage - Page Blob/P10 (Units)     US West
# 19                  Standard IO - Page Blob/Disk (GB)         NaN
#
#                meterSubCategory  quantity  \
# 0             Locally Redundant  0.001389
# 1                           NaN  0.000500
# 2                           NaN  0.059841
# 3   Standard_D4_v3 VM (Windows)  0.766682
# 4                           NaN  0.000100
# 5                           DNS  0.000804
# 6           Public IP Addresses  0.900000
# 7                           NaN  0.009300
# 8                           NaN  0.004500
# 9                           NaN  1.619603
# 10                          NaN  0.058600
# 11                          DNS  0.013441
# 12                          NaN  0.000500
# 13                          NaN  0.004900
# 14                          NaN  0.009600
# 15                          NaN  0.014400
# 16                          DNS  0.000694
# 17                          DNS  0.032258
# 18            Locally Redundant  0.033336
# 19            Locally Redundant  0.000006
#
#                           subscriptionId        unit  \
# 0   3e6b71a1-1c47-4188-a4dc-793259a87549       Units
# 1   3e6b71a1-1c47-4188-a4dc-793259a87549     10,000s
# 2   3e6b71a1-1c47-4188-a4dc-793259a87549          GB
# 3   3e6b71a1-1c47-4188-a4dc-793259a87549       Hours
# 4   3e6b71a1-1c47-4188-a4dc-793259a87549     10,000s
# 5   3e6b71a1-1c47-4188-a4dc-793259a87549  1M Queries
# 6   3e6b71a1-1c47-4188-a4dc-793259a87549       Hours
# 7   3e6b71a1-1c47-4188-a4dc-793259a87549     10,000s
# 8   3e6b71a1-1c47-4188-a4dc-793259a87549     10,000s
# 9   3e6b71a1-1c47-4188-a4dc-793259a87549          GB
# 10  3e6b71a1-1c47-4188-a4dc-793259a87549     10,000s
# 11  3e6b71a1-1c47-4188-a4dc-793259a87549   DNS Zones
# 12  3e6b71a1-1c47-4188-a4dc-793259a87549     10,000s
# 13  3e6b71a1-1c47-4188-a4dc-793259a87549     10,000s
# 14  3e6b71a1-1c47-4188-a4dc-793259a87549     10,000s
# 15  3e6b71a1-1c47-4188-a4dc-793259a87549     10,000s
# 16  3e6b71a1-1c47-4188-a4dc-793259a87549  1M Queries
# 17  3e6b71a1-1c47-4188-a4dc-793259a87549   DNS Zones
# 18  3e6b71a1-1c47-4188-a4dc-793259a87549       Units
# 19  3e6b71a1-1c47-4188-a4dc-793259a87549          GB
#
#                  usageEndTime             usageStartTime
# 0   2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 1   2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 2   2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 3   2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 4   2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 5   2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 6   2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 7   2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 8   2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 9   2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 10  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 11  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 12  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 13  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 14  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00
# 15  2018-06-14T00:00:00+00:00  2018-06-13T00:00:00+00:00
# 16  2018-06-14T00:00:00+00:00  2018-06-13T00:00:00+00:00
# 17  2018-06-14T00:00:00+00:00  2018-06-13T00:00:00+00:00
# 18  2018-06-14T00:00:00+00:00  2018-06-13T00:00:00+00:00
# 19  2018-06-14T00:00:00+00:00  2018-06-13T00:00:00+00:00

# %%
# https://msdn.microsoft.com/en-us/library/azure/mt219001.aspx
# Note the query is by *reported* time, but the return is by *usage* time
# "... we ask callers to query by Reported Time to ensure that they get all the usage 
# events reported within a specific time period within the billing system. Even though the query is made 
# with the Reported Time, the usage response is aggregated by the resource usage time, which is the useful 
# pivot for callers."
# We queried from 6-12 to 6-14. This usage shows up on 6-12 to 6-13, but if you quesry
# 6-12 to 6-13 this record will not be picked up as it was *reported* 6-13 to 6-14

df_usage_detail.loc[df_usage_detail['meterId'] == "9995d93a-7d35-4d3f-9c69-7a7fea447ef4"]
# Out:
#   infoFields                                       instanceData meterCategory  \
# 2         {}  {"Microsoft.Resources":{"resourceUri":"/subscr...    Networking
#
#                                 meterId               meterName meterRegion  \
# 2  9995d93a-7d35-4d3f-9c69-7a7fea447ef4  Data Transfer Out (GB)      Zone 1
#
#   meterSubCategory  quantity                        subscriptionId unit  \
# 2              NaN  0.059841  3e6b71a1-1c47-4188-a4dc-793259a87549   GB
#
#                 usageEndTime             usageStartTime
# 2  2018-06-13T00:00:00+00:00  2018-06-12T00:00:00+00:00

# %%
s['subscriptionId']
# Out:
# '3e6b71a1-1c47-4188-a4dc-793259a87549'

# %%
invoice_list_url = "https://management.azure.com:443/subscriptions/{subscriptionId}/providers/Microsoft.Billing/invoices?api-version=2017-04-24-preview".format(subscriptionId = subscription)
invoice_list_url
# Out:
# 'https://management.azure.com:443/subscriptions/3e6b71a1-1c47-4188-a4dc-793259a87549/providers/Microsoft.Billing/invoices?api-version=2017-04-24-preview'

# %%
response = requests.get(invoice_list_url, allow_redirects=False, headers = {'Authorization': 'Bearer %s' %access_token})

# %%
invoice_name = response.json()['value'][0]['name']

# %%
invoice_url = "https://management.azure.com:443/subscriptions/{subscriptionId}/providers/Microsoft.Billing/invoices/{invoiceName}?api-version=2017-04-24-preview".format(subscriptionId = subscription, invoiceName=invoice_name)

# %%
response = requests.get(invoice_url, allow_redirects=False, headers = {'Authorization': 'Bearer %s' %access_token})

# %%
invoice_pdf_url = response.json()['properties']['downloadUrl']['url']

# %%
response = requests.get(invoice_pdf_url)

# %%
f = open('invoice.pdf', 'wb')
f.write(response.content)
f.close()

# %%
# pickle everything
import pickle
pickle.dump( df_usage, open( "df_usage.p", "wb" ) )
pickle.dump( df_rates, open( "df_rates.p", "wb" ) )

# %%
# TODO
# aggregate usage on rate
# left join usage on rates
# iter 
#   process row into rated record
